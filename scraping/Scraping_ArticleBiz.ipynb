# %%
import bs4
import time
from datetime import datetime
from bs4 import BeautifulSoup  
import pandas as pd
import scipy as sc
import numpy as np
import requests

# %%
def get_article_html(url):
    html = requests.get(url)
    soup = BeautifulSoup(html.content,"html.parser")
    time.sleep(5) 
    return soup

# %%
def get_data_articlebiz_web(soup):
    
    articles = soup.find_all('div',attrs={'class':'mb-4 card border-primary'})
    
    # Declaration
    articles_topic = []
    articles_content = []

    for article in articles:
        # Get article's topic
        topic = article.find("a").get_text()
        articles_topic.append(topic)

        # Get article's content
       
        url_of_article = article.find('a')['href']
        print(url_of_article)

        soup = get_article_html(url_of_article)

        content = soup.find('div',attrs={'class':'clearfix'}).find_all("p")
        full_content = ""
        if content != None:
            for paragraph in content:
                full_content = full_content + " " + paragraph.get_text().strip()
        articles_content.append(full_content) 
        
    return articles_topic, articles_content

# %%
def insert_data_to_csv(topic, category, content):
    # Create dataframe
    data = pd.DataFrame({
    "topic": topic,
    "category": category,
    "content": content
    })
    data.to_csv(f'articlebiz Scraping-{category}-{datetime.now().strftime("%d-%m-%Y")}.csv', mode='a')

# %%
categories = ["politics", "business", "pets", "news-society", "arts-entertainment", "travel-leisure", "social-issues", "autos-trucks", "health-fitness", "shopping", "computers-technology", "finance", "home", "sports-recreations"]
print("Start scraping from articlebiz!")
for category in categories:
    soup = get_article_html(f"https://articlebiz.com/category/{category}")
    topic, content = get_data_articlebiz_web(soup)
    insert_data_to_csv(topic, category, content)
print("Finish scraping from articlebiz.com!")
# Out:
# Start scraping from articlebiz!
# 9 Health Benefits of Kale
# https://articlebiz.com/article/1051904896-9-health-benefits-of-kale
# The Importance of Skincare & the Benefits of Natural Skin Care Products
# https://articlebiz.com/article/1051904741-the-importance-of-skincare-the-benefits-of-natural-skin-care-products
# 7 Easy Ways Tomatoes Can Benefit You Quickly
# https://articlebiz.com/article/1051904216-7-easy-ways-tomatoes-can-benefit-you-quickly
# Ikenga Ogbo on Careers in Public Health
# https://articlebiz.com/article/1051902804-ikenga-ogbo-on-careers-in-public-health
# Is There a Correlation Between the Gut and Eczema?
# https://articlebiz.com/article/1051902802-is-there-a-correlation-between-the-gut-and-eczema
# St. Augustine Occupational Therapy at Tender Care PPEC
# https://articlebiz.com/article/1051895738-st-augustine-occupational-therapy-at-tender-care-ppec
# Why do I have skin tags popping up?
# https://articlebiz.com/article/1051895240-why-do-i-have-skin-tags-popping-up
# Are skin tags and stretch marks related?
# https://articlebiz.com/article/1051895239-are-skin-tags-and-stretch-marks-related
# Are skin tags and rash related?
# https://articlebiz.com/article/1051895234-are-skin-tags-and-rash-related
# What are the best essential oils for skin tags removal?
# https://articlebiz.com/article/1051895231-what-are-the-best-essential-oils-for-skin-tags-removal
# The Importance of Professionalism in Healthcare
# https://articlebiz.com/article/1051892931-the-importance-of-professionalism-in-healthcare
# The Biggest Cause of Burnout and What You Can Do About It
# https://articlebiz.com/article/1051892926-the-biggest-cause-of-burnout-and-what-you-can-do-about-it
# What is Endovascular Surgery?
# https://articlebiz.com/article/1051892923-what-is-endovascular-surgery
# 10 ways quitting smoking weed changed my life
# https://articlebiz.com/article/1051891774-10-ways-quitting-smoking-weed-changed-my-life
# How to remove skin tags fast in 3 days?
